# %%
import pandas as pd
import warnings
df=pd.read_csv("cardio_train.csv",sep=";")

# %%
warnings.filterwarnings('ignore')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.to_csv("cardio1.csv",index=False)

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df["weight"]=df["weight"].astype(int)

# %%
df["age"]=df["age"]/365

# %%
df
# Out:
#           id        age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 0          0  50.391781       2     168      62    110     80            1
# 1          1  55.419178       1     156      85    140     90            3
# 2          2  51.663014       1     165      64    130     70            3
# 3          3  48.282192       2     169      82    150    100            1
# 4          4  47.873973       1     156      56    100     60            1
# ...      ...        ...     ...     ...     ...    ...    ...          ...
# 69995  99993  52.712329       2     168      76    120     80            1
# 69996  99995  61.920548       1     158     126    140     90            2
# 69997  99996  52.235616       2     183     105    180     90            3
# 69998  99998  61.454795       1     163      72    135     80            1
# 69999  99999  56.273973       1     170      72    120     80            2
#
#        gluc  smoke  alco  active  cardio
# ...

# %%
df['age'] = df['age'].round().astype(int)

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2     168      62    110     80            1     1
# 1          1   55       1     156      85    140     90            3     1
# 2          2   52       1     165      64    130     70            3     1
# 3          3   48       2     169      82    150    100            1     1
# 4          4   48       1     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       2     168      76    120     80            1     1
# 69996  99995   62       1     158     126    140     90            2     2
# 69997  99996   52       2     183     105    180     90            3     1
# 69998  99998   61       1     163      72    135     80            1     2
# 69999  99999   56       1     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df["gender"]=df["gender"].map({2:1,1:0})

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
#df.drop(df[(df['height'] > df['height'].quantile(0.98)) | (df['height'] < df['height'].quantile(0.02))].index,inplace=True)
#df.drop(df[(df['weight'] > df['weight'].quantile(0.98)) | (df['weight'] < df['weight'].quantile(0.02))].index,inplace=True)

# %%
#df.drop(df[(df['ap_hi'] > df['ap_hi'].quantile(0.98)) | (df['ap_hi'] < df['ap_hi'].quantile(0.02))].index,inplace=True)
#df.drop(df[(df['ap_lo'] > df['ap_lo'].quantile(0.98)) | (df['ap_lo'] < df['ap_lo'].quantile(0.02))].index,inplace=True)

# %%
for i in ['height','weight','ap_hi','ap_lo','age']:
    mean = df[i].mean()
    std = df[i].std()
    below_outlier = mean - 3*std
    above_outlier = mean + 3*std
    df = df[(df[i]>=below_outlier) & (df[i]<=above_outlier)]

# %%
'''for c in ['height','weight','ap_hi','ap_lo','age']:
    q3 = df[c].quantile(0.75)
    q1 = df[c].quantile(0.25)
    iqr = q3 - q1
    upper = q3 + 3 * iqr
    lower = q1 - 3 * iqr
    mean = df[i].mean()
    std = df[i].std()
    below_outlier = mean - 3*std
    above_outlier = mean + 3*std
    df = df[(df[c]>=lower) & (df[c]<=upper)]'''
# Out:
# "for c in ['height','weight','ap_hi','ap_lo','age']:\n    q3 = df[c].quantile(0.75)\n    q1 = df[c].quantile(0.25)\n    iqr = q3 - q1\n    upper = q3 + 3 * iqr\n    lower = q1 - 3 * iqr\n    mean = df[i].mean()\n    std = df[i].std()\n    below_outlier = mean - 3*std\n    above_outlier = mean + 3*std\n    df = df[(df[c]>=lower) & (df[c]<=upper)]"

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69994  99992   58       0     165      80    150     80            1     1
# 69995  99993   53       1     168      76    120     80            1     1
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
#df["bmi"] = df["weight"] / (df["height"]/100)**2

# %%
df["age"].value_counts()
# Out:
# age
# 56    5867
# 54    5830
# 58    5532
# 60    5301
# 52    5148
# 50    5122
# 62    3821
# 64    3805
# 48    3108
# 46    2885
# 44    2760
# 40    2631
# 42    2568
# 55    1465
# 57    1408
# 53    1367
# 59    1313
# 51    1312
# 61    1186
# 49    1032
# 63     990
# 45     743
# 41     741
# 47     731
# 43     665
# 39     394
# 65     342
# Name: count, dtype: int64

# %%
df[df["height"]<100].value_counts()
# Out:
# id     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  cardio
# 309    60   1       76      55      120    80     1            1     0      0     1       0         1
# 41661  52   0       60      69      110    70     1            1     0      0     0       0         1
# 93223  51   0       99      60      90     60     1            1     0      0     1       0         1
# 92008  58   0       66      63      12     80     1            1     0      0     0       1         1
# 91523  50   0       59      57      125    67     1            1     0      0     0       0         1
# 79917  58   0       96      59      90     60     1            1     0      0     1       1         1
# 76116  56   1       67      80      120    80     1            1     0      0     0       1         1
# 73386  42   1       70      69      120    80     1            1     0      0     0       0         1
# ...

# %%
df[df["height"]>100]
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df[df["weight"]>150].value_counts()
# Out:
# id     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  cardio
# 552    46   1       165     169     120    80     1            1     0      0     1       0         1
# 78159  62   1       177     160     170    110    3            3     0      0     1       1         1
# 50043  64   0       170     152     200    140    1            3     0      0     1       1         1
# 52564  54   0       161     181     180    1100   2            1     0      0     1       1         1
# 53670  55   0       162     175     140    1000   1            1     0      0     1       1         1
# 58175  60   0       154     162     120    80     1            1     0      0     1       0         1
# 59768  56   0       164     164     140    90     3            3     0      0     1       1         1
# 60631  53   0       160     155     120    80     1            1     0      0     1       1         1
# ...

# %%
df[df["weight"]<150]
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df[df["ap_hi"]<df["ap_lo"]].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df["ap_hi"]>df["ap_lo"]]
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df[df["ap_hi"]>300].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["ap_hi"].max()
# Out:
# 240

# %%
df= df[(df['ap_lo']<300) & (df['ap_hi']<300)]
df= df[(df['ap_lo']>20) & (df['ap_hi']>20)]
df=df[df['ap_hi']>df['ap_lo']]
df = df[(df['height']<250) & (df['weight']<160)]
df=df[(df["ap_hi"]<=300) & (df["height"]>=100) & (df["weight"]>=35) & (df["ap_hi"]>=df["ap_lo"]) & (df["ap_hi"]>=0) & (df["ap_lo"]>=0)]

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df=df[(df["ap_hi"]<=300) & (df["height"]>=100) & (df["weight"]>=35) & (df["ap_hi"]>=df["ap_lo"]) & (df["ap_hi"]>=0) & (df["ap_lo"]>=0)]

# %%
df["bmi"] = df["weight"] / (df["height"]/100)**2

# %%
df['map']=df['ap_lo']+(df['ap_hi']-df['ap_lo'])/3

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       1     168      62    110     80            1     1
# 1          1   55       0     156      85    140     90            3     1
# 2          2   52       0     165      64    130     70            3     1
# 3          3   48       1     169      82    150    100            1     1
# 4          4   48       0     156      56    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1     168      76    120     80            1     1
# 69996  99995   62       0     158     126    140     90            2     2
# 69997  99996   52       1     183     105    180     90            3     1
# 69998  99998   61       0     163      72    135     80            1     2
# 69999  99999   56       0     170      72    120     80            2     1
#
#        smoke  alco  active  cardio        bmi         map
# ...

# %%
from scipy.stats import jarque_bera

# %%
result = jarque_bera(df)

test_statistic = result[0]
p_value = result[1]

print(f"Jarque-Bera test statistic: {test_statistic}")
print(f"p-value: {p_value}")
# Out:
# Jarque-Bera test statistic: 15589444.59216667
# p-value: 0.0

# %%
del df['id']

# %%
#del df['gender']

# %%
del df['alco']

# %%
#del df['gluc']

# %%
df
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       1     168      62    110     80            1     1      0
# 1       55       0     156      85    140     90            3     1      0
# 2       52       0     165      64    130     70            3     1      0
# 3       48       1     169      82    150    100            1     1      0
# 4       48       0     156      56    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   53       1     168      76    120     80            1     1      1
# 69996   62       0     158     126    140     90            2     2      0
# 69997   52       1     183     105    180     90            3     1      0
# 69998   61       0     163      72    135     80            1     2      0
# 69999   56       0     170      72    120     80            2     1      0
#
#        alco  active  cardio        bmi         map
# ...

# %%
df.to_csv("mini3.csv",index=False)

# %%
df['weight'].value_counts()
# Out:
# weight
# 65    3713
# 70    3633
# 68    2745
# 75    2643
# 60    2635
#       ...
# 36       4
# 34       3
# 35       3
# 32       3
# 33       1
# Name: count, Length: 86, dtype: int64

# %%
df[df['weight']==33]
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 48080  68667   53       0     143      33    100     60            1     1
#
#        smoke  alco  active  cardio
# 48080      0     0       1       0

# %%
df['weight'].min()
# Out:
# 11

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from sklearn.preprocessing import MinMaxScaler
from sklearn import tree
from sklearn.metrics import f1_score

# %%
dx = df.copy()
for c in  ['age','height','weight','ap_hi','ap_lo']:
    df = dx[ dx[c] == dx[c].mode()[0]  ]

# %%
df
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke  active  \
# 0       50       1     168      62    110     80            1      0       1
# 1       55       0     156      85    140     90            3      0       1
# 2       52       0     165      64    130     70            3      0       0
# 3       48       1     169      82    150    100            1      0       1
# 4       48       0     156      56    100     60            1      0       0
# ...    ...     ...     ...     ...    ...    ...          ...    ...     ...
# 69994   58       0     165      80    150     80            1      0       1
# 69995   53       1     168      76    120     80            1      1       1
# 69997   52       1     183     105    180     90            3      0       0
# 69998   61       0     163      72    135     80            1      0       0
# 69999   56       0     170      72    120     80            2      0       1
#
#        cardio        bmi         map
# ...

# %%
scaler = MinMaxScaler()
scaler.fit(df[ ['age','height','weight','ap_hi','ap_lo','bmi','map'] ])
df[ ['age','height','weight','ap_hi','ap_lo',"bmi",'map'] ] = (scaler.transform(df[ ['age','height','weight','ap_hi','ap_lo','bmi','map'] ]))

# %%
df
# Out:
#             age  gender    height    weight     ap_hi     ap_lo  cholesterol  \
# 0      0.571429       1  0.635514  0.217742  0.277778  0.328947            1
# 1      0.714286       0  0.523364  0.403226  0.444444  0.394737            3
# 2      0.628571       0  0.607477  0.233871  0.388889  0.263158            3
# 3      0.514286       1  0.644860  0.379032  0.500000  0.460526            1
# 4      0.514286       0  0.523364  0.169355  0.222222  0.197368            1
# ...         ...     ...       ...       ...       ...       ...          ...
# 69995  0.657143       1  0.635514  0.330645  0.333333  0.328947            1
# 69996  0.914286       0  0.542056  0.733871  0.444444  0.394737            2
# 69997  0.628571       1  0.775701  0.564516  0.666667  0.394737            3
# 69998  0.885714       0  0.588785  0.298387  0.416667  0.328947            1
# 69999  0.742857       0  0.654206  0.298387  0.333333  0.328947            2
#
# ...

# %%
df.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.023090 -0.084209  0.056997  0.209967  0.156622
# gender      -0.023090  1.000000  0.512766  0.157174  0.062160  0.067286
# height      -0.084209  0.512766  1.000000  0.304706  0.018274  0.036141
# weight       0.056997  0.157174  0.304706  1.000000  0.272689  0.254489
# ap_hi        0.209967  0.062160  0.018274  0.272689  1.000000  0.733791
# ap_lo        0.156622  0.067286  0.036141  0.254489  0.733791  1.000000
# cholesterol  0.155293 -0.036997 -0.054504  0.142502  0.195418  0.161337
# gluc         0.098865 -0.021321 -0.020696  0.107549  0.094169  0.074735
# smoke       -0.047810  0.338944  0.193807  0.067839  0.027726  0.025131
# active      -0.010281  0.005927 -0.008739 -0.018845 -0.001177 -0.000804
# cardio       0.239243  0.007100 -0.012586  0.181374  0.427990  0.339573
# bmi          0.102654 -0.110993 -0.224174  0.851683  0.266310  0.238412
# ...

# %%
df = df.sample(frac = 1.0)

# %%
df
# Out:
#             age  gender    height    weight     ap_hi     ap_lo  cholesterol  \
# 599    0.971429       0  0.514019  0.241935  0.333333  0.328947            3
# 68283  0.742857       1  0.663551  0.435484  0.333333  0.328947            1
# 58890  0.628571       1  0.700935  0.483871  0.333333  0.328947            1
# 26085  0.571429       0  0.616822  0.330645  0.444444  0.394737            1
# 41632  0.771429       0  0.560748  0.403226  0.333333  0.328947            1
# ...         ...     ...       ...       ...       ...       ...          ...
# 32203  0.314286       0  0.635514  0.508065  0.333333  0.328947            1
# 24831  0.628571       0  0.560748  0.282258  0.388889  0.394737            1
# 45852  0.685714       0  0.598131  0.233871  0.444444  0.460526            1
# 21817  0.914286       0  0.700935  0.604839  0.444444  0.394737            3
# 18230  0.914286       1  0.728972  0.250000  0.500000  0.131579            3
#
# ...

# %%
target="cardio"
limit = int(len(df) * 0.60)
train = df[:limit]
test = df[limit:]
train_y = train[target]
test_y = test[target]
del train[target]
del test[target]

# %%
clf = tree.DecisionTreeClassifier(max_depth=5)
clf = clf.fit(train,train_y)

# %%
print("Accuracy:",metrics.accuracy_score(test_y,clf.predict(test)))
print('accure_train' , metrics.accuracy_score(train_y , clf.predict(train)))
print("f1 score:",metrics.f1_score(test_y, clf.predict(test)))
# Out:
# Accuracy: 0.7283064251612668
# accure_train 0.732390601841728
# f1 score: 0.6968896117096972

# %%
clf = tree.DecisionTreeClassifier(max_depth=5) 
clf.fit( train, train_y )
y_pred = clf.predict( test )
correct = test_y == y_pred
test['REAL'] = test_y
test['PRED'] = y_pred
test['CORRECT'] = test['PRED'] == test['REAL']
test['TP'] = (test['PRED'] == 1) & (test['REAL'] == 1)
test['TN'] = (test['PRED'] == 0) & (test['REAL'] == 0)
test['FP'] = (test['PRED'] == 1) & (test['REAL'] == 0)
test['FN'] = (test['PRED'] == 0) & (test['REAL'] == 1)

for c in ['CORRECT','TP','TN','FP','FN']:
    test[c] = test[c].astype(int)
fn = test['FN'].mean() * 20
fp = test['FP'].mean() * 3
tp = test['TP'].mean() * 15
tn = test['TN'].mean() * 20

TP = sum(1 for true_label, predicted_label in zip(test['REAL'], test['PRED']) if true_label == predicted_label)
TI = len(test['REAL'])
test_accuracy = TP / TI
test_accuracy_percentage = test_accuracy * 100

print("Test Accuracy:", test_accuracy)
weighted_accuracy = (tp + tn) / ( fn+fp+tp+tn )
recall=tp/(tp+fn)
Specificity=tn/(tn+fp)
Precision=tp/(tp+fp)
f1_score=2*recall*Precision/(recall+Precision)
print(weighted_accuracy)
print(f1_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1159], line 3
#       1 clf = tree.DecisionTreeClassifier(max_depth=5)
#       2 clf.fit( train, train_y )
# ----> 3 y_pred = clf.predict( test )
#       4 correct = test_y == y_pred
#       5 test['REAL'] = test_y
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:500, in BaseDecisionTree.predict(self, X, check_input)
#     477 """Predict class or regression value for X.
#     478
#     479 For a classification model, the predicted class for each sample in X is
#    (...)
#     497     The predicted classes, or the predict values.
#     498 """
#     499 check_is_fitted(self)
# --> 500 X = self._validate_X_predict(X, check_input)
#     501 proba = self.tree_.predict(X)
#     502 n_samples = X.shape[0]
#
# ...

# %%
target_name = 'cardio'
data_target = df[target_name]
df = df.drop([target_name], axis=1)
train, test, target, target_test = train_test_split(df, data_target, test_size=0.2, random_state=0)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(train, target)
acc_decision_tree = round(decision_tree.score(train, target) * 100, 2)
acc_decision_tree
# Out:
# 97.61

# %%
acc_test_decision_tree = round(decision_tree.score(test, target_test) * 100, 2)
acc_test_decision_tree
# Out:
# 63.67

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
random_forest = GridSearchCV(estimator=RandomForestClassifier(), param_grid={'n_estimators': [100, 300]}, cv=5).fit(train, target)
random_forest.fit(train, target)
acc_random_forest = round(random_forest.score(train, target) * 100, 2)
print(acc_random_forest,random_forest.best_params_)
# Out:
# 100.0 {'n_estimators': 300}

# %%
acc_test_random_forest = round(random_forest.score(test, target_test) * 100, 2)
acc_test_random_forest
# Out:
# 71.03
